# %% [markdown]
# <a href="https://colab.research.google.com/github/Hoperablack/Airplane_Passenger_sats/blob/main/Loan_DataAnalysis%26Prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import  pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime

# %%
file_path =  '/content/drive/MyDrive/DataSet/loan_data.csv'
loan_data = pd.read_csv(file_path)

# %%
loan_data.head()
# Out:
#                                                 Text  Income  Credit_Score  \
# 0  I need a loan to pay for an international vaca...   26556           581
# 1  I want to make home improvements like installi...  197392           389
# 2  I need a loan for home renovation, including a...   44561           523
# 3  I need funds to buy new furniture and applianc...  190363           729
# 4           I need a loan to start a small business.   61853           732
#
#    Loan_Amount  DTI_Ratio Employment_Status  Approval
# 0         8314      79.26          employed  Rejected
# 1       111604      22.14          employed  Rejected
# 2        34118      45.44          employed  Rejected
# 3       118757      10.22        unemployed  Rejected
# 4        19210      44.13          employed  Approved

# %%
loan_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24000 entries, 0 to 23999
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Text               24000 non-null  object
#  1   Income             24000 non-null  int64
#  2   Credit_Score       24000 non-null  int64
#  3   Loan_Amount        24000 non-null  int64
#  4   DTI_Ratio          24000 non-null  float64
#  5   Employment_Status  24000 non-null  object
#  6   Approval           24000 non-null  object
# dtypes: float64(1), int64(3), object(3)
# memory usage: 1.3+ MB

# %%
loan_data.describe()
# Out:
#               Income  Credit_Score    Loan_Amount     DTI_Ratio
# count   24000.000000  24000.000000   24000.000000  24000.000000
# mean   110377.552708    575.720333   44356.154833     34.719167
# std     51729.677627    159.227621   34666.604785     32.322471
# min     20001.000000    300.000000    1005.000000      2.530000
# 25%     65635.750000    437.000000   16212.000000     14.507500
# 50%    110464.000000    575.000000   35207.000000     24.860000
# 75%    155187.000000    715.000000   65622.750000     41.840000
# max    200000.000000    850.000000  158834.000000    246.330000

# %%
loan_data.isnull().sum()
# Out:
# Text                 0
# Income               0
# Credit_Score         0
# Loan_Amount          0
# DTI_Ratio            0
# Employment_Status    0
# Approval             0
# dtype: int64

# %%
duplicate_row = [loan_data.duplicated()]
duplicate_row
# Out:
# [0        False
#  1        False
#  2        False
#  3        False
#  4        False
#           ...
#  23995    False
#  23996    False
#  23997    False
#  23998    False
#  23999    False
#  Length: 24000, dtype: bool]

# %%
average_income = [loan_data['Income'].mean()]
average_income
# Out:
# [np.float64(110377.55270833333)]

# %%
average_ratio = [loan_data['DTI_Ratio'].mean()]
average_ratio
# Out:
# [np.float64(34.7191675)]

# %%
average_creditscore = [loan_data['Credit_Score'].mean()]
average_creditscore
# Out:
# [np.float64(575.7203333333333)]

# %%
Em_status = loan_data['Employment_Status'].value_counts()
Em_status
# Out:
# Employment_Status
# unemployed    12007
# employed      11993
# Name: count, dtype: int64

# %%
App_status = loan_data['Approval'].value_counts()
App_status
# Out:
# Approval
# Rejected    20067
# Approved     3933
# Name: count, dtype: int64

# %%
Approved_loans = loan_data[loan_data['Approval'] == 'Approved']
Total_approved_amount = Approved_loans['Loan_Amount'].sum()
Total_approved_amount
# Out:
# np.int64(148131622)

# %%
Rejected_loans = loan_data[loan_data['Approval'] == 'Rejected']
Total_rejected_amount = Rejected_loans['Loan_Amount'].sum()
Total_rejected_amount
# Out:
# np.int64(916416094)

# %% [markdown]
# ##Model Development

# %%
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import OneHotEncoder,LabelEncoder
from sklearn.metrics import mean_squared_error as msc

# %%
from sklearn.preprocessing import OneHotEncoder
import joblib

# %%
enc.fit(loan_data[['Employment_Status']])  # Fit the encoder with the data
employment_encoded = enc.transform(loan_data[['Employment_Status']]).toarray()  # Now transform the data

# %%
model = LinearRegression()

# %%
loan_data.Employment_Status.unique()
# Out:
# array(['employed', 'unemployed'], dtype=object)

# %%
enc = OneHotEncoder()
enc.fit(loan_data[['Employment_Status']])
one_hot = enc.transform(loan_data[['Employment_Status']]).toarray()
one_hot
# Out:
# array([[1., 0.],
#        [1., 0.],
#        [1., 0.],
#        ...,
#        [1., 0.],
#        [0., 1.],
#        [1., 0.]])

# %%
loan_data[['employed','unemployed']] = one_hot
loan_data.head()
# Out:
#                                                 Text  Income  Credit_Score  \
# 0  I need a loan to pay for an international vaca...   26556           581
# 1  I want to make home improvements like installi...  197392           389
# 2  I need a loan for home renovation, including a...   44561           523
# 3  I need funds to buy new furniture and applianc...  190363           729
# 4           I need a loan to start a small business.   61853           732
#
#    Loan_Amount  DTI_Ratio Employment_Status  Approval  employed  unemployed
# 0         8314      79.26          employed  Rejected       1.0         0.0
# 1       111604      22.14          employed  Rejected       1.0         0.0
# 2        34118      45.44          employed  Rejected       1.0         0.0
# 3       118757      10.22        unemployed  Rejected       0.0         1.0
# 4        19210      44.13          employed  Approved       1.0         0.0

# %%
from re import M
le = LabelEncoder()
le.fit(loan_data[['Approval']])
loan_data['Approval'] = le.transform(loan_data[['Approval']])
loan_data.head()
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_label.py:93: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_label.py:129: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True)
#                                                 Text  Income  Credit_Score  \
# 0  I need a loan to pay for an international vaca...   26556           581
# 1  I want to make home improvements like installi...  197392           389
# 2  I need a loan for home renovation, including a...   44561           523
# 3  I need funds to buy new furniture and applianc...  190363           729
# ...

# %%
inputs = loan_data[['Loan_Amount', 'Income', 'Credit_Score', 'DTI_Ratio', 'employed', 'unemployed']]

# %%
loan_data = loan_data.drop(columns='Employment_Status')
loan_data.head()
# Out:
#                                                 Text  Income  Credit_Score  \
# 0  I need a loan to pay for an international vaca...   26556           581
# 1  I want to make home improvements like installi...  197392           389
# 2  I need a loan for home renovation, including a...   44561           523
# 3  I need funds to buy new furniture and applianc...  190363           729
# 4           I need a loan to start a small business.   61853           732
#
#    Loan_Amount  DTI_Ratio  Approval  employed  unemployed
# 0         8314      79.26         1       1.0         0.0
# 1       111604      22.14         1       1.0         0.0
# 2        34118      45.44         1       1.0         0.0
# 3       118757      10.22         1       0.0         1.0
# 4        19210      44.13         0       1.0         0.0

# %%
targets = loan_data['Approval']

# %%
model.fit(inputs, targets)
# Out:
# LinearRegression()

# %%
# Generate predictions
predictions = model.predict(inputs)

# %%
import joblib
joblib.dump(LinearRegression(), 'reg_model.joblib')
# Out:
# ['reg_model.joblib']

# %%
from google.colab import files
files.download('reg_model.joblib')

# %%
# !pip freeze > requirements.txt

# %%
from google.colab import files
files.download("requirements.txt")
